# %%
# Read csv File
import pandas as pd
df=pd.read_csv("Students_Marks_SY1_SY2_SY3.csv")
df
# Out:
#      Roll No               Name department Division  Math  Physics  Chemistry  \
# 0        1.0   Student_sy_1_A_1       sy_1        A  52.0     60.0       90.0
# 1        2.0   Student_sy_1_A_2       sy_1        A  52.0     53.0       59.0
# 2        3.0   Student_sy_1_A_3       sy_1        A  44.0     94.0       95.0
# 3        4.0   Student_sy_1_A_4       sy_1        A  45.0     42.0       72.0
# 4        5.0   Student_sy_1_A_5       sy_1        A  42.0     78.0       65.0
# ..       ...                ...        ...      ...   ...      ...        ...
# 715     26.0  Student_sy_3_H_26       sy_3        H  85.0     69.0       71.0
# 716     27.0  Student_sy_3_H_27       sy_3        H  71.0    100.0       86.0
# 717     28.0  Student_sy_3_H_28       sy_3        H  84.0     88.0       69.0
# 718     29.0  Student_sy_3_H_29       sy_3        H  93.0     40.0       75.0
# 719     30.0  Student_sy_3_H_30       sy_3        H  80.0     65.0       54.0
#
#      English  Computer
# ...

# %%
# Add a column Name is : Total
df['Total'] = df[['Math', 'Physics', 'Chemistry', 'English', 'Computer']].sum(axis=1)
df
# Out:
#      Roll No               Name department Division  Math  Physics  Chemistry  \
# 0        1.0   Student_sy_1_A_1       sy_1        A  52.0     60.0       90.0
# 1        2.0   Student_sy_1_A_2       sy_1        A  52.0     53.0       59.0
# 2        3.0   Student_sy_1_A_3       sy_1        A  44.0     94.0       95.0
# 3        4.0   Student_sy_1_A_4       sy_1        A  45.0     42.0       72.0
# 4        5.0   Student_sy_1_A_5       sy_1        A  42.0     78.0       65.0
# ..       ...                ...        ...      ...   ...      ...        ...
# 715     26.0  Student_sy_3_H_26       sy_3        H  85.0     69.0       71.0
# 716     27.0  Student_sy_3_H_27       sy_3        H  71.0    100.0       86.0
# 717     28.0  Student_sy_3_H_28       sy_3        H  84.0     88.0       69.0
# 718     29.0  Student_sy_3_H_29       sy_3        H  93.0     40.0       75.0
# 719     30.0  Student_sy_3_H_30       sy_3        H  80.0     65.0       54.0
#
#      English  Computer  Total
# ...

# %%
# Add a column name : Percentage
df['Percentage'] = (df['Total'] / 500) * 100
df
# Out:
#      Roll No               Name department Division  Math  Physics  Chemistry  \
# 0        1.0   Student_sy_1_A_1       sy_1        A  52.0     60.0       90.0
# 1        2.0   Student_sy_1_A_2       sy_1        A  52.0     53.0       59.0
# 2        3.0   Student_sy_1_A_3       sy_1        A  44.0     94.0       95.0
# 3        4.0   Student_sy_1_A_4       sy_1        A  45.0     42.0       72.0
# 4        5.0   Student_sy_1_A_5       sy_1        A  42.0     78.0       65.0
# ..       ...                ...        ...      ...   ...      ...        ...
# 715     26.0  Student_sy_3_H_26       sy_3        H  85.0     69.0       71.0
# 716     27.0  Student_sy_3_H_27       sy_3        H  71.0    100.0       86.0
# 717     28.0  Student_sy_3_H_28       sy_3        H  84.0     88.0       69.0
# 718     29.0  Student_sy_3_H_29       sy_3        H  93.0     40.0       75.0
# 719     30.0  Student_sy_3_H_30       sy_3        H  80.0     65.0       54.0
#
# ...

# %%
# import liberary numpy as np
import numpy as np

# %%
# Using np.where function & add Grade for using percentage column
df["grade"]=np.where(df["Percentage"]>90,"A",
            (np.where(df["Percentage"]>80,"B",
            (np.where(df["Percentage"]>70,"C",
            (np.where(df["Percentage"]>60,"D",
            (np.where(df["Percentage"]>50,"E",
            (np.where(df["Percentage"]>40,"F","Fail")))))))))))
df
# Out:
#      Roll No               Name department Division  Math  Physics  Chemistry  \
# 0        1.0   Student_sy_1_A_1       sy_1        A  52.0     60.0       90.0
# 1        2.0   Student_sy_1_A_2       sy_1        A  52.0     53.0       59.0
# 2        3.0   Student_sy_1_A_3       sy_1        A  44.0     94.0       95.0
# 3        4.0   Student_sy_1_A_4       sy_1        A  45.0     42.0       72.0
# 4        5.0   Student_sy_1_A_5       sy_1        A  42.0     78.0       65.0
# ..       ...                ...        ...      ...   ...      ...        ...
# 715     26.0  Student_sy_3_H_26       sy_3        H  85.0     69.0       71.0
# 716     27.0  Student_sy_3_H_27       sy_3        H  71.0    100.0       86.0
# 717     28.0  Student_sy_3_H_28       sy_3        H  84.0     88.0       69.0
# 718     29.0  Student_sy_3_H_29       sy_3        H  93.0     40.0       75.0
# 719     30.0  Student_sy_3_H_30       sy_3        H  80.0     65.0       54.0
#
# ...

# %%
# Find a mean_score
mean_scores = df["Total"].mean()
print(mean_scores)
# Out:
# 348.9236111111111

# %%
# Using describe function 
df.describe()
# Out:
#           Roll No        Math     Physics   Chemistry     English    Computer  \
# count  720.000000  720.000000  720.000000  720.000000  720.000000  720.000000
# mean    15.500000   69.673611   69.134722   70.345833   69.008333   70.761111
# std      8.661458   18.187032   17.368298   17.653554   17.451062   17.067196
# min      1.000000   40.000000   40.000000   40.000000   40.000000   40.000000
# 25%      8.000000   53.000000   54.000000   54.000000   53.000000   57.000000
# 50%     15.500000   70.500000   69.000000   71.000000   69.000000   70.000000
# 75%     23.000000   86.000000   84.000000   85.250000   84.000000   85.000000
# max     30.000000  100.000000  100.000000  100.000000  100.000000  100.000000
#
#             Total  Percentage
# count  720.000000  720.000000
# mean   348.923611   69.784722
# std     39.019285    7.803857
# min    246.000000   49.200000
# 25%    320.000000   64.000000
# 50%    348.000000   69.600000
# 75%    374.000000   74.800000
# ...

# %%
# get 1st 5 column to using HEAD function
df.head(5)
# Out:
#    Roll No              Name department Division  Math  Physics  Chemistry  \
# 0      1.0  Student_sy_1_A_1       sy_1        A  52.0     60.0       90.0
# 1      2.0  Student_sy_1_A_2       sy_1        A  52.0     53.0       59.0
# 2      3.0  Student_sy_1_A_3       sy_1        A  44.0     94.0       95.0
# 3      4.0  Student_sy_1_A_4       sy_1        A  45.0     42.0       72.0
# 4      5.0  Student_sy_1_A_5       sy_1        A  42.0     78.0       65.0
#
#    English  Computer  Total  Percentage grade
# 0    100.0      40.0  342.0        68.4     D
# 1     93.0      46.0  303.0        60.6     D
# 2     50.0      79.0  362.0        72.4     C
# 3    100.0      91.0  350.0        70.0     D
# 4     58.0      94.0  337.0        67.4     D

# %%
# count uniq values in column name : Grade
print(df[["grade"]].value_counts())
# Out:
# grade
# D        311
# C        275
# E         66
# B         62
# A          4
# F          2
# Name: count, dtype: int64

# %%
# Find null values 
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# department    0
# Division      0
# Math          0
# Physics       0
# Chemistry     0
# English       0
# Computer      0
# Total         0
# Percentage    0
# grade         0
# dtype: int64

# %%
# Find the Average values per Subjects

Subject_name = ["Math","Physics","Chemistry","English","Computer"]
Average_scores = df[Subject_name].mean()
print("per subject Average score is:\n",Average_scores)
# Out:
# per subject Average score is:
#  Math         69.673611
# Physics      69.134722
# Chemistry    70.345833
# English      69.008333
# Computer     70.761111
# dtype: float64

# %%
# Department wise Average Total marks

Department_avg = df.groupby("department")["Total"].mean()
print("department wise total Average marks is:\n",Department_avg)
# Out:
# department wise total Average marks is:
#  department
# sy_1    344.958333
# sy_2    348.583333
# sy_3    353.229167
# Name: Total, dtype: float64

# %%
# Find subject wise pass students:
pass_counts = (df[Subject_name]>=40).sum()
print("count the subjectwise pass students is:\n",pass_counts)
# Out:
# count the subjectwise pass students is:
#  Math         720
# Physics      720
# Chemistry    720
# English      720
# Computer     720
# dtype: int64

# %%
# Find the specific number of pass students
pass_counts = (df[Subject_name]>=40).sum()
num_pass_counts = pass_counts.sum()
print("count the subjectwise pass students is:\n",num_pass_counts)
# Out:
# count the subjectwise pass students is:
#  3600

# %%
# Find subject wise fail students:

Fail_counts = (df[Subject_name]<=40).sum()
print("count the subjectwise fail students is:\n",Fail_counts)
# Out:
# count the subjectwise fail students is:
#  Math         17
# Physics      18
# Chemistry     8
# English      12
# Computer     13
# dtype: int64

# %%
# Find the specific number of fail students
Fail_counts = (df[Subject_name]<40).sum()
num_Fail_counts = Fail_counts.sum()
print("count the subjectwise pass students is:\n",num_Fail_counts)
# Out:
# count the subjectwise pass students is:
#  0

# %%
# count the subject wise student there is out of 50 :
pass_students = (df[Subject_name]>=50).sum()
print("count the subject wise students there is out of 50 marks is :\n",pass_students)
# Out:
# count the subject wise students there is out of 50 marks is :
#  Math         589
# Physics      602
# Chemistry    603
# English      602
# Computer     620
# dtype: int64

# %%
# Count the subject wise specific number there is out of 50:

students = (df[Subject_name]>=50).sum()
num_students = students.sum()
print("count the subject wise students there is out of 50 marks is :\n",num_students)
# Out:
# count the subject wise students there is out of 50 marks is :
#  3016

# %%
# find number of students per division

division_counts = df['Division'].value_counts()
print("Number of students per division:\n", division_counts)
# Out:
# Number of students per division:
#  Division
# A    90
# B    90
# C    90
# D    90
# E    90
# F    90
# G    90
# H    90
# Name: count, dtype: int64

# %%
division_counts = df['Division'].count()
print("Number of students per division:\n", division_counts)
# Out:
# Number of students per division:
#  720

# %%
df.to_csv('processed_students_data.csv', index=False)
df
# Out:
#      Roll No               Name department Division  Math  Physics  Chemistry  \
# 0        1.0   Student_sy_1_A_1       sy_1        A  52.0     60.0       90.0
# 1        2.0   Student_sy_1_A_2       sy_1        A  52.0     53.0       59.0
# 2        3.0   Student_sy_1_A_3       sy_1        A  44.0     94.0       95.0
# 3        4.0   Student_sy_1_A_4       sy_1        A  45.0     42.0       72.0
# 4        5.0   Student_sy_1_A_5       sy_1        A  42.0     78.0       65.0
# ..       ...                ...        ...      ...   ...      ...        ...
# 715     26.0  Student_sy_3_H_26       sy_3        H  85.0     69.0       71.0
# 716     27.0  Student_sy_3_H_27       sy_3        H  71.0    100.0       86.0
# 717     28.0  Student_sy_3_H_28       sy_3        H  84.0     88.0       69.0
# 718     29.0  Student_sy_3_H_29       sy_3        H  93.0     40.0       75.0
# 719     30.0  Student_sy_3_H_30       sy_3        H  80.0     65.0       54.0
#
# ...

# %%
# PLots

# %%
# Bar plot ::::Average Marks by Subjects

import matplotlib.pyplot as plt
import numpy as np

subjects = ['Math', 'Physics', 'Chemistry', 'English', 'Computer']
avg_marks = df[subjects].mean()

plt.figure(figsize=(6,5))
plt.bar(subjects, avg_marks, color='pink')
plt.title("Average Marks by Subject")
plt.ylabel("Average Marks")
plt.xlabel("Subjects")
# Out:
# Text(0.5, 0, 'Subjects')

# %%
# Heatmap:::::::::Subject wise Corelation Metrix

import seaborn as sns

plt.figure(figsize=(8,6))
corr_matrix = df[['Math', 'Physics', 'Chemistry', 'English', 'Computer']].corr()

sns.heatmap(corr_matrix, annot=True, cmap='cubehelix', linewidths=0.6)
plt.title("Subject Wise Marks Correlation")
plt.show()

# %%
#Topper pr Department:::::::::::
df['Percentage'] = df[subjects].sum(axis=1) / len(subjects)
topper = df.loc[df.groupby('department')['Percentage'].idxmax()]
counts = topper['department'].value_counts()

plt.figure(figsize=(8,5))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=50, colors=['#8e44ad', '#16a085', '#f39c12'], wedgeprops={'width':0.5})
plt.title("Topper per Department")
plt.tight_layout()
plt.show()

# %%
# KNN Model::::::::::::Using Machine Learning Prediction

import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.preprocessing import StandardScaler

f=pd.read_csv("Students_Marks_SY1_SY2_SY3.csv")
df=pd.DataFrame(f)
df
# Out:
#      Roll No               Name department Division  Math  Physics  Chemistry  \
# 0        1.0   Student_sy_1_A_1       sy_1        A  52.0     60.0       90.0
# 1        2.0   Student_sy_1_A_2       sy_1        A  52.0     53.0       59.0
# 2        3.0   Student_sy_1_A_3       sy_1        A  44.0     94.0       95.0
# 3        4.0   Student_sy_1_A_4       sy_1        A  45.0     42.0       72.0
# 4        5.0   Student_sy_1_A_5       sy_1        A  42.0     78.0       65.0
# ..       ...                ...        ...      ...   ...      ...        ...
# 715     26.0  Student_sy_3_H_26       sy_3        H  85.0     69.0       71.0
# 716     27.0  Student_sy_3_H_27       sy_3        H  71.0    100.0       86.0
# 717     28.0  Student_sy_3_H_28       sy_3        H  84.0     88.0       69.0
# 718     29.0  Student_sy_3_H_29       sy_3        H  93.0     40.0       75.0
# 719     30.0  Student_sy_3_H_30       sy_3        H  80.0     65.0       54.0
#
#      English  Computer
# ...

# %%
x = df[["Math","Physics","Chemistry","English","Computer"]]
y=df["department"]

x=pd.get_dummies(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=KNeighborsClassifier(n_neighbors=8)

model.fit(x_train,y_train)
pre=model.predict(x_test)

acc=accuracy_score(y_test,pre)*100
print(f"accuracy is {acc}")

con=confusion_matrix(y_test,pre)
print(con)

cl=classification_report(y_test,pre)
print(f"classification_report is {cl}")
# Out:
# accuracy is 36.11111111111111
# [[28 13 15]
#  [27 10 11]
#  [16 10 14]]
# classification_report is               precision    recall  f1-score   support
#
#         sy_1       0.39      0.50      0.44        56
#         sy_2       0.30      0.21      0.25        48
#         sy_3       0.35      0.35      0.35        40
#
#     accuracy                           0.36       144
#    macro avg       0.35      0.35      0.35       144
# weighted avg       0.35      0.36      0.35       144

# %%
x_test
# Out:
#      Math  Physics  Chemistry  English  Computer
# 340  72.0     43.0       59.0     56.0      66.0
# 290  76.0     78.0       56.0     44.0      70.0
# 54   63.0     73.0       46.0     42.0      64.0
# 198  43.0     48.0       45.0     54.0      83.0
# 453  89.0     73.0       84.0     50.0      78.0
# ..    ...      ...        ...      ...       ...
# 164  63.0     59.0       90.0     62.0      82.0
# 165  83.0     41.0       49.0     77.0      59.0
# 199  52.0     50.0       92.0     89.0      78.0
# 132  74.0     43.0       88.0     75.0      48.0
# 501  88.0     59.0       77.0     61.0      95.0
#
# [144 rows x 5 columns]

# %%
x = df[["Math","Physics","Chemistry","English","Computer"]]
y=df["Division"]

x=pd.get_dummies(x)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
model=KNeighborsClassifier(n_neighbors=8)

model.fit(x_train,y_train)
pre=model.predict(x_test)

acc=accuracy_score(y_test,pre)*100
print(f"accuracy is {acc}")

con=confusion_matrix(y_test,pre)
print(con)

cl=classification_report(y_test,pre)
print(f"classification_report is {cl}")
# Out:
# accuracy is 12.5
# [[ 1  1  2  1  1  3  0  1]
#  [ 4  2  4  3  1  3  0  2]
#  [ 6  4  2  2  1  4  3  1]
#  [ 3  4  0 10  2  0  2  2]
#  [ 2  1  3  6  1  2  1  1]
#  [ 7  3  3  0  1  0  1  0]
#  [ 1  6  1  2  1  3  1  1]
#  [ 1  4  5  2  4  1  3  1]]
# classification_report is               precision    recall  f1-score   support
#
#            A       0.04      0.10      0.06        10
#            B       0.08      0.11      0.09        19
#            C       0.10      0.09      0.09        23
#            D       0.38      0.43      0.41        23
#            E       0.08      0.06      0.07        17
#            F       0.00      0.00      0.00        15
#            G       0.09      0.06      0.07        16
#            H       0.11      0.05      0.07        21
#
#     accuracy                           0.12       144
#    macro avg       0.11      0.11      0.11       144
# weighted avg       0.13      0.12      0.12       144

# %%
x_test
# Out:
#      Math  Physics  Chemistry  English  Computer
# 340  72.0     43.0       59.0     56.0      66.0
# 290  76.0     78.0       56.0     44.0      70.0
# 54   63.0     73.0       46.0     42.0      64.0
# 198  43.0     48.0       45.0     54.0      83.0
# 453  89.0     73.0       84.0     50.0      78.0
# ..    ...      ...        ...      ...       ...
# 164  63.0     59.0       90.0     62.0      82.0
# 165  83.0     41.0       49.0     77.0      59.0
# 199  52.0     50.0       92.0     89.0      78.0
# 132  74.0     43.0       88.0     75.0      48.0
# 501  88.0     59.0       77.0     61.0      95.0
#
# [144 rows x 5 columns]

# %%
pre1=model.predict([[43,48,45,54,83]])
pre1
# Out:
# C:\Users\KUNJAL PATEL\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array(['F'], dtype=object)

# %%
# Accuracyy model::::::;
import matplotlib.pyplot as plt

plt.figure(figsize=(5,5))
plt.pie([acc, 100 - acc], labels=["Correct", "Incorrect"],
        colors=['#2c3e50', '#95a5a6'], autopct='%1.1f%%', startangle=90)
plt.title("Accuracy of Model")
plt.show()

# %%
# Train-Test-split :::::::::::
train_size = len(x_train)
test_size = len(x_test)

plt.figure(figsize=(5,5))
plt.pie([train_size, test_size], labels=["Train", "Test"],
        autopct='%1.1f%%', colors=['#1abc9c', '#f39c12'], startangle=90)
plt.title("Train-Test Split")
plt.show()

# %%
df.to_csv('student_result.csv', index=False)
df
